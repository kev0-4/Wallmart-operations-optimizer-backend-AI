# %%
import pandas as pd

# %%
df_Trends = pd.read_csv("..\data\external\EcommerceTrends\ecommerce_product_dataset2.csv")

# %%
df_Trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ProductID                          1000 non-null   int64
#  1   ProductName                        1000 non-null   object
#  2   Category                           1000 non-null   object
#  3   Price                              1000 non-null   float64
#  4   Rating                             1000 non-null   float64
#  5   NumReviews                         1000 non-null   int64
#  6   StockQuantity                      1000 non-null   int64
#  7   Discount                           1000 non-null   float64
#  8   Sales                              1000 non-null   int64
#  9   DateAdded                          1000 non-null   object
#  10  City                               1000 non-null   object
#  11  Stock In Vast or Limited Quantity  1000 non-null   bool
# dtypes: bool(1), float64(3), int64(4), object(4)
# memory usage: 87.0+ KB

# %%
df_Trends.head(1)
# Out:
#    ProductID ProductName     Category   Price  Rating  NumReviews  \
# 0          1  Headphones  Electronics  400.31     1.7        3772
#
#    StockQuantity  Discount  Sales   DateAdded         City  \
# 0             20      0.08    466  11/10/2023  Albuquerque
#
#    Stock In Vast or Limited Quantity
# 0                               True

# %%
## Imoporting next dtaset

# %%
df_customerSegmentation = pd.read_csv("..\data\external\Customer Segmentation\customer_segmentation_data.csv")

# %%
df_customerSegmentation.head(2)
# Out:
#    id  age  gender  income  spending_score  membership_years  \
# 0   1   38  Female   99342              90                 3
# 1   2   21  Female   78852              60                 2
#
#    purchase_frequency preferred_category  last_purchase_amount
# 0                  24          Groceries                113.53
# 1                  42             Sports                 41.93

# %%
df_customerSegmentation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   gender                1000 non-null   object
#  3   income                1000 non-null   int64
#  4   spending_score        1000 non-null   int64
#  5   membership_years      1000 non-null   int64
#  6   purchase_frequency    1000 non-null   int64
#  7   preferred_category    1000 non-null   object
#  8   last_purchase_amount  1000 non-null   float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 70.4+ KB

# %%
## Imoporting next dtaset

# %%
df_WallmartSales = pd.read_csv("..\data\external\Walmart Sales\Walmart_Sales.csv")

# %%
df_WallmartSales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df_WallmartSales.head(1)
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010     1643690.9             0        42.31       2.572
#
#           CPI  Unemployment
# 0  211.096358         8.106

# %%
## Data augmentation

# %%
import numpy as np
from datetime import datetime, timedelta

# %%
def augment_trends(df):
    df = df.drop(['City'], axis=1)
    
    df['DateAdded'] = pd.to_datetime(df['DateAdded'])    
    df['DaysSinceAdded'] = (datetime.now() - df['DateAdded']).dt.days
    
    df['TrendScore'] = (df['Sales'] * 0.4 + 
                        df['NumReviews'] * 0.3 + 
                        df['Rating'] * 20 + 
                        df['DaysSinceAdded'] * -0.1)
    df['TrendScore'] = df['TrendScore'].clip(0, 100)
    

    df['SalesVelocity'] = df['Sales'] / df['DaysSinceAdded'].clip(1)
    df['RestockUrgency'] = ((1 - df['StockQuantity'] / df['Sales'].clip(1)) * 
                            df['SalesVelocity'] * 10)
    df['RestockUrgency'] = df['RestockUrgency'].clip(0, 10)
    
    df['EstimatedCost'] = df['Price'] * (1 - df['Discount']) * 0.7  # Assuming 30% markup
    df['ProfitMargin'] = (df['Price'] - df['EstimatedCost']) / df['Price']
    
    return df

# %%
def augment_customer_segmentation(df):
    df['CustomerValue'] = (df['spending_score'] * 0.4 + 
                           df['purchase_frequency'] * 10 + 
                           df['membership_years'] * 5 + 
                           df['income'] * 0.0001)
    
    df['AgeGroup'] = pd.cut(df['age'], bins=[0, 18, 30, 45, 60, 100], 
                            labels=['<18', '18-30', '31-45', '46-60', '60+'])
    
    df['IncomeGroup'] = pd.qcut(df['income'], q=5, 
                                labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
    
    df['LoyaltyScore'] = df['membership_years'] * df['purchase_frequency']
    
    df['LastPurchaseRecency'] = np.random.randint(1, 365, size=len(df))
    
    return df

# %%
def augment_walmart_sales(df):
    df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
    
    df['Year'] = df['Date'].dt.year
    df['Month'] = df['Date'].dt.month
    
    df['SeasonalityIndex'] = df.groupby(['Store', 'Month'])['Weekly_Sales'].transform(
        lambda x: x / x.mean())
    
    df = df.sort_values(['Store', 'Date'])
    df['RollingAvgSales'] = df.groupby('Store')['Weekly_Sales'].rolling(window=4).mean().reset_index(0, drop=True)
    
    df['SalesGrowthRate'] = df.groupby('Store')['Weekly_Sales'].pct_change()
    
    df['EconomicIndex'] = (df['CPI'] / df['CPI'].mean()) * (1 - df['Unemployment'] / 100)
    
    # Create Temperature Category
    df['TempCategory'] = pd.cut(df['Temperature'], bins=[-float('inf'), 32, 50, 70, 90, float('inf')],
                                labels=['Freezing', 'Cold', 'Moderate', 'Warm', 'Hot'])
    
    return df

# %%
# -------------------- #

# %%
df_Trends_augmented = augment_trends(df_Trends)
df_customerSegmentation_augmented = augment_customer_segmentation(df_customerSegmentation)
df_WallmartSales_augmented = augment_walmart_sales(df_WallmartSales)

# %%
print("Head of df_Trends_augmented:")
df_Trends_augmented.info()
df_Trends_augmented.head(1)
# Out:
# Head of df_Trends_augmented:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ProductID                          1000 non-null   int64
#  1   ProductName                        1000 non-null   object
#  2   Category                           1000 non-null   object
#  3   Price                              1000 non-null   float64
#  4   Rating                             1000 non-null   float64
#  5   NumReviews                         1000 non-null   int64
#  6   StockQuantity                      1000 non-null   int64
#  7   Discount                           1000 non-null   float64
#  8   Sales                              1000 non-null   int64
#  9   DateAdded                          1000 non-null   datetime64[ns]
#  10  Stock In Vast or Limited Quantity  1000 non-null   bool
#  11  DaysSinceAdded                     1000 non-null   int64
#  12  TrendScore                         1000 non-null   float64
#  13  SalesVelocity                      1000 non-null   float64
#  14  RestockUrgency                     1000 non-null   float64
#  15  EstimatedCost                      1000 non-null   float64
#  16  ProfitMargin                       1000 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(8), int64(5), object(2)
# memory usage: 126.1+ KB
#    ProductID ProductName     Category   Price  Rating  NumReviews  \
# 0          1  Headphones  Electronics  400.31     1.7        3772
#
#    StockQuantity  Discount  Sales  DateAdded  \
# 0             20      0.08    466 2023-11-10
#
#    Stock In Vast or Limited Quantity  DaysSinceAdded  TrendScore  \
# 0                               True             276       100.0
#
#    SalesVelocity  RestockUrgency  EstimatedCost  ProfitMargin
# 0       1.688406            10.0      257.79964         0.356

# %%
print("Head of df_customerSegmentation_augmented:")
df_customerSegmentation_augmented.info()
df_customerSegmentation_augmented.head(1)
# Out:
# Head of df_customerSegmentation_augmented:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   gender                1000 non-null   object
#  3   income                1000 non-null   int64
#  4   spending_score        1000 non-null   int64
#  5   membership_years      1000 non-null   int64
#  6   purchase_frequency    1000 non-null   int64
#  7   preferred_category    1000 non-null   object
#  8   last_purchase_amount  1000 non-null   float64
#  9   CustomerValue         1000 non-null   float64
#  10  AgeGroup              1000 non-null   category
#  11  IncomeGroup           1000 non-null   category
#  12  LoyaltyScore          1000 non-null   int64
#  13  LastPurchaseRecency   1000 non-null   int32
# dtypes: category(2), float64(2), int32(1), int64(7), object(2)
# memory usage: 92.3+ KB
#    id  age  gender  income  spending_score  membership_years  \
# 0   1   38  Female   99342              90                 3
#
#    purchase_frequency preferred_category  last_purchase_amount  CustomerValue  \
# 0                  24          Groceries                113.53       300.9342
#
#   AgeGroup IncomeGroup  LoyaltyScore  LastPurchaseRecency
# 0    31-45      Medium            72                  352

# %%
print("Head of df_WallmartSales_augmented:")
df_WallmartSales_augmented.info()
df_WallmartSales_augmented.head(1)
# Out:
# Head of df_WallmartSales_augmented:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Store             6435 non-null   int64
#  1   Date              6435 non-null   datetime64[ns]
#  2   Weekly_Sales      6435 non-null   float64
#  3   Holiday_Flag      6435 non-null   int64
#  4   Temperature       6435 non-null   float64
#  5   Fuel_Price        6435 non-null   float64
#  6   CPI               6435 non-null   float64
#  7   Unemployment      6435 non-null   float64
#  8   Year              6435 non-null   int32
#  9   Month             6435 non-null   int32
#  10  SeasonalityIndex  6435 non-null   float64
#  11  RollingAvgSales   6300 non-null   float64
#  12  SalesGrowthRate   6390 non-null   float64
#  13  EconomicIndex     6435 non-null   float64
#  14  TempCategory      6435 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(9), int32(2), int64(2)
# memory usage: 660.2 KB
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05     1643690.9             0        42.31       2.572
#
#           CPI  Unemployment  Year  Month  SeasonalityIndex  RollingAvgSales  \
# 0  211.096358         8.106  2010      2          1.011227              NaN
#
#    SalesGrowthRate  EconomicIndex TempCategory
# 0              NaN        1.13059         Cold

# %%
# ------ #

# %%
import random
from scipy import stats

# 1. Prompt Generation

def generate_trend_prompt(df):
    product = df.sample(1)
    return f"What's the current trend for {product['ProductName'].values[0]} in the {product['Category'].values[0]} category? Its TrendScore is {product['TrendScore'].values[0]:.2f}."

def generate_inventory_prompt(df):
    product = df.sample(1)
    return f"Should we restock {product['ProductName'].values[0]}? Its current stock is {product['StockQuantity'].values[0]} units, and its RestockUrgency is {product['RestockUrgency'].values[0]:.2f}."

def generate_sales_prompt(df):
    store = df.sample(1)
    return f"Predict next week's sales for Store {store['Store'].values[0]}. Current EconomicIndex is {store['EconomicIndex'].values[0]:.2f}, and last week's sales were ${store['Weekly_Sales'].values[0]:,.2f}."

def generate_customer_prompt(df):
    customer = df.sample(1)
    return f"Describe the buying patterns of the {customer['AgeGroup'].values[0]} age group in the {customer['IncomeGroup'].values[0]} income bracket. Their average CustomerValue is {customer['CustomerValue'].values[0]:.2f}."

def generate_prompts(df_trends, df_customers, df_sales, n=100):
    prompts = []
    for _ in range(n):
        prompt_type = random.choice(['trend', 'inventory', 'sales', 'customer'])
        if prompt_type == 'trend':
            prompts.append(generate_trend_prompt(df_trends))
        elif prompt_type == 'inventory':
            prompts.append(generate_inventory_prompt(df_trends))
        elif prompt_type == 'sales':
            prompts.append(generate_sales_prompt(df_sales))
        else:
            prompts.append(generate_customer_prompt(df_customers))
    return prompts

# Generate prompts
prompts = generate_prompts(df_Trends_augmented, df_customerSegmentation_augmented, df_WallmartSales_augmented, n=100)

print("Sample Prompts:")
for prompt in prompts[:5]:
    print(prompt)

# 2. Correlation Analysis
def perform_correlation_analysis(df_trends, df_customers, df_sales):
    trends_num = df_trends.select_dtypes(include=[np.number])
    customers_num = df_customers.select_dtypes(include=[np.number])
    sales_num = df_sales.select_dtypes(include=[np.number])

    all_num = pd.concat([trends_num, customers_num, sales_num], axis=1)

    correlation_matrix = all_num.corr()

    strong_correlations = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > 0.5:  
                strong_correlations.append((correlation_matrix.columns[i], 
                                            correlation_matrix.columns[j], 
                                            correlation_matrix.iloc[i, j]))

    return strong_correlations

# Generate prompts
prompts = generate_prompts(df_Trends_augmented, df_customerSegmentation_augmented, df_WallmartSales_augmented, n=100)

print("Sample Prompts:")
for prompt in prompts[:]:
    print(prompt)

correlations = perform_correlation_analysis(df_Trends_augmented, df_customerSegmentation_augmented, df_WallmartSales_augmented)

print("\nStrong Correlations:")
for col1, col2, corr in correlations:
    print(f"{col1} and {col2}: Correlation = {corr:.2f}")

# 3. Generate Prompts Based on Correlations

def generate_correlation_prompt(correlation):
    col1, col2, corr = correlation
    if corr > 0:
        relationship = "positive"
    else:
        relationship = "negative"
    
    return f"There's a strong {relationship} correlation ({corr:.2f}) between {col1} and {col2}. How can we leverage this insight for business strategy?"

correlation_prompts = [generate_correlation_prompt(corr) for corr in correlations[:5]]  # Using top 5 correlations

print("\nCorrelation-Based Prompts:")
for prompt in correlation_prompts:
    print(prompt)
# Out:
# Sample Prompts:
# Should we restock Wool Socks? Its current stock is 753 units, and its RestockUrgency is 0.00.
# Should we restock Fantasy Book? Its current stock is 645 units, and its RestockUrgency is 10.00.
# Should we restock Cleanser? Its current stock is 94 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 18-30 age group in the Medium income bracket. Their average CustomerValue is 116.19.
# Should we restock Jacket? Its current stock is 491 units, and its RestockUrgency is 10.00.
# Sample Prompts:
# Predict next week's sales for Store 1. Current EconomicIndex is 1.14, and last week's sales were $2,387,950.20.
# Predict next week's sales for Store 40. Current EconomicIndex is 0.77, and last week's sales were $954,396.85.
# Predict next week's sales for Store 35. Current EconomicIndex is 0.73, and last week's sales were $800,662.82.
# Predict next week's sales for Store 41. Current EconomicIndex is 1.05, and last week's sales were $1,356,689.88.
# What's the current trend for Phone Case in the Mobile phone accessories category? Its TrendScore is 100.00.
# Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 484.87.
# What's the current trend for Saucepan in the Cookware category? Its TrendScore is 100.00.
# What's the current trend for Body Scrub in the Bath and body category? Its TrendScore is 100.00.
# Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 439.05.
# What's the current trend for Brushes in the Art and crafting materials category? Its TrendScore is 100.00.
# Should we restock Wine Glass? Its current stock is 535 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 31-45 age group in the Very Low income bracket. Their average CustomerValue is 99.15.
# Should we restock Ankle Socks? Its current stock is 180 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 18-30 age group in the High income bracket. Their average CustomerValue is 446.70.
# Should we restock Smartwatch? Its current stock is 232 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 60+ age group in the Medium income bracket. Their average CustomerValue is 127.22.
# What's the current trend for Paint Set in the Art and crafting materials category? Its TrendScore is 100.00.
# Describe the buying patterns of the 18-30 age group in the Very High income bracket. Their average CustomerValue is 245.19.
# What's the current trend for Electric Blanket in the Blankets category? Its TrendScore is 100.00.
# Describe the buying patterns of the 46-60 age group in the Low income bracket. Their average CustomerValue is 360.31.
# Should we restock Earbuds? Its current stock is 111 units, and its RestockUrgency is 0.00.
# Should we restock Nail Clippers? Its current stock is 93 units, and its RestockUrgency is 10.00.
# What's the current trend for Eau de Parfum in the Perfume and cologne category? Its TrendScore is 100.00.
# Should we restock Oil Filter? Its current stock is 712 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 18-30 age group in the Low income bracket. Their average CustomerValue is 215.64.
# Should we restock Coffee Maker? Its current stock is 733 units, and its RestockUrgency is 0.00.
# What's the current trend for Dutch Oven in the Cookware category? Its TrendScore is 100.00.
# Predict next week's sales for Store 19. Current EconomicIndex is 0.73, and last week's sales were $1,374,863.10.
# Predict next week's sales for Store 25. Current EconomicIndex is 1.09, and last week's sales were $583,364.02.
# Predict next week's sales for Store 40. Current EconomicIndex is 0.73, and last week's sales were $1,087,578.78.
# Should we restock Rain Jacket? Its current stock is 867 units, and its RestockUrgency is 0.00.
# Should we restock Body Scrub? Its current stock is 55 units, and its RestockUrgency is 2.78.
# Should we restock Winter Coat? Its current stock is 130 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 508.52.
# Predict next week's sales for Store 12. Current EconomicIndex is 0.65, and last week's sales were $1,016,019.47.
# Describe the buying patterns of the 31-45 age group in the High income bracket. Their average CustomerValue is 363.41.
# Should we restock Cotton Sheets? Its current stock is 341 units, and its RestockUrgency is 10.00.
# Predict next week's sales for Store 25. Current EconomicIndex is 1.12, and last week's sales were $640,912.18.
# Predict next week's sales for Store 25. Current EconomicIndex is 1.14, and last week's sales were $728,525.60.
# Should we restock Sparkling Wine? Its current stock is 160 units, and its RestockUrgency is 10.00.
# Should we restock Earbuds? Its current stock is 570 units, and its RestockUrgency is 10.00.
# Should we restock Lipstick? Its current stock is 121 units, and its RestockUrgency is 10.00.
# What's the current trend for Water Bottle in the Drinkware category? Its TrendScore is 100.00.
# Describe the buying patterns of the 46-60 age group in the Very High income bracket. Their average CustomerValue is 179.57.
# Should we restock Bamboo Sheets? Its current stock is 757 units, and its RestockUrgency is 10.00.
# Should we restock Protein Powder? Its current stock is 519 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 31-45 age group in the High income bracket. Their average CustomerValue is 363.41.
# Describe the buying patterns of the 46-60 age group in the Medium income bracket. Their average CustomerValue is 475.80.
# Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 81.58.
# What's the current trend for White Wine in the Wine category? Its TrendScore is 100.00.
# What's the current trend for Dutch Oven in the Cookware category? Its TrendScore is 100.00.
# Describe the buying patterns of the 18-30 age group in the Medium income bracket. Their average CustomerValue is 95.95.
# Should we restock Body Lotion? Its current stock is 727 units, and its RestockUrgency is 0.00.
# Should we restock Panties? Its current stock is 971 units, and its RestockUrgency is 0.00.
# Describe the buying patterns of the 18-30 age group in the Medium income bracket. Their average CustomerValue is 359.59.
# Should we restock Screen Protector? Its current stock is 825 units, and its RestockUrgency is 10.00.
# What's the current trend for Silk Sheets in the Bedsheets category? Its TrendScore is 100.00.
# Predict next week's sales for Store 40. Current EconomicIndex is 0.73, and last week's sales were $1,007,574.67.
# What's the current trend for Electric Bike in the Bicycles category? Its TrendScore is 100.00.
# Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 489.62.
# Should we restock Nail Clippers? Its current stock is 810 units, and its RestockUrgency is 10.00.
# What's the current trend for Soy Candle in the Candles category? Its TrendScore is 100.00.
# Predict next week's sales for Store 23. Current EconomicIndex is 0.76, and last week's sales were $1,423,289.90.
# Should we restock Brake Pads? Its current stock is 335 units, and its RestockUrgency is 10.00.
# What's the current trend for Canvas in the Art and crafting materials category? Its TrendScore is 100.00.
# What's the current trend for Wool Socks in the Socks category? Its TrendScore is 100.00.
# Should we restock White Wine? Its current stock is 365 units, and its RestockUrgency is 10.00.
# Predict next week's sales for Store 31. Current EconomicIndex is 1.13, and last week's sales were $1,352,401.08.
# Should we restock Digital Art? Its current stock is 530 units, and its RestockUrgency is 10.00.
# Should we restock Framed Poster? Its current stock is 155 units, and its RestockUrgency is 10.00.
# What's the current trend for Cuticle Oil in the Nail care category? Its TrendScore is 100.00.
# Predict next week's sales for Store 44. Current EconomicIndex is 0.69, and last week's sales were $280,785.76.
# Predict next week's sales for Store 1. Current EconomicIndex is 1.13, and last week's sales were $1,399,662.07.
# Predict next week's sales for Store 9. Current EconomicIndex is 1.17, and last week's sales were $490,981.78.
# Predict next week's sales for Store 41. Current EconomicIndex is 1.05, and last week's sales were $1,402,233.69.
# Predict next week's sales for Store 1. Current EconomicIndex is 1.15, and last week's sales were $1,534,849.64.
# Predict next week's sales for Store 33. Current EconomicIndex is 0.67, and last week's sales were $240,044.57.
# Should we restock Sparkling Wine? Its current stock is 313 units, and its RestockUrgency is 10.00.
# What's the current trend for Smartwatch in the Electronics category? Its TrendScore is 100.00.
# Predict next week's sales for Store 13. Current EconomicIndex is 0.68, and last week's sales were $1,785,823.37.
# Predict next week's sales for Store 19. Current EconomicIndex is 0.71, and last week's sales were $1,591,453.39.
# Describe the buying patterns of the 60+ age group in the High income bracket. Their average CustomerValue is 147.06.
# Should we restock Sweater? Its current stock is 401 units, and its RestockUrgency is 10.00.
# Predict next week's sales for Store 39. Current EconomicIndex is 1.15, and last week's sales were $1,414,564.53.
# Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 551.82.
# Should we restock Brake Pads? Its current stock is 235 units, and its RestockUrgency is 10.00.
# What's the current trend for Jacket in the Clothing category? Its TrendScore is 100.00.
# Should we restock Beeswax Candle? Its current stock is 522 units, and its RestockUrgency is 0.00.
# Should we restock Soy Candle? Its current stock is 908 units, and its RestockUrgency is 0.00.
# Predict next week's sales for Store 19. Current EconomicIndex is 0.74, and last week's sales were $1,352,809.50.
# Describe the buying patterns of the 18-30 age group in the High income bracket. Their average CustomerValue is 532.77.
# What's the current trend for Scented Candle in the Candles category? Its TrendScore is 100.00.
# Should we restock Sweater? Its current stock is 19 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 18-30 age group in the Low income bracket. Their average CustomerValue is 318.43.
# Describe the buying patterns of the 46-60 age group in the Medium income bracket. Their average CustomerValue is 578.78.
# Should we restock Spark Plugs? Its current stock is 680 units, and its RestockUrgency is 10.00.
# What's the current trend for Phone Case in the Mobile phone accessories category? Its TrendScore is 100.00.
# Should we restock Jacket? Its current stock is 264 units, and its RestockUrgency is 10.00.
# Describe the buying patterns of the 46-60 age group in the Very High income bracket. Their average CustomerValue is 293.21.
# Should we restock Nail Polish? Its current stock is 11 units, and its RestockUrgency is 10.00.
#
# Strong Correlations:
# SalesVelocity and Sales: Correlation = 0.64
# SalesVelocity and DaysSinceAdded: Correlation = -0.60
# RestockUrgency and Sales: Correlation = 0.75
# RestockUrgency and SalesVelocity: Correlation = 0.50
# EstimatedCost and Price: Correlation = 0.93
# ProfitMargin and Discount: Correlation = 1.00
# id and ProductID: Correlation = 1.00
# CustomerValue and purchase_frequency: Correlation = 0.99
# LoyaltyScore and membership_years: Correlation = 0.69
# LoyaltyScore and purchase_frequency: Correlation = 0.69
# LoyaltyScore and CustomerValue: Correlation = 0.75
# Store and ProductID: Correlation = 0.99
# Store and id: Correlation = 0.99
# Year and Fuel_Price: Correlation = 0.78
# RollingAvgSales and Weekly_Sales: Correlation = 0.98
# SalesGrowthRate and SeasonalityIndex: Correlation = 0.68
# EconomicIndex and CPI: Correlation = 1.00
#
# Correlation-Based Prompts:
# There's a strong positive correlation (0.64) between SalesVelocity and Sales. How can we leverage this insight for business strategy?
# There's a strong negative correlation (-0.60) between SalesVelocity and DaysSinceAdded. How can we leverage this insight for business strategy?
# There's a strong positive correlation (0.75) between RestockUrgency and Sales. How can we leverage this insight for business strategy?
# There's a strong positive correlation (0.50) between RestockUrgency and SalesVelocity. How can we leverage this insight for business strategy?
# There's a strong positive correlation (0.93) between EstimatedCost and Price. How can we leverage this insight for business strategy?

# %%
# -------- #

# %%
import random

def generate_trend_answer(df, product_name, category, trend_score):
    sales = df[df['ProductName'] == product_name]['Sales'].values[0]
    rating = df[df['ProductName'] == product_name]['Rating'].values[0]
    
    if trend_score > 75:
        trend = "very popular"
    elif trend_score > 50:
        trend = "moderately popular"
    else:
        trend = "not very popular"
    
    return f"The {product_name} in the {category} category is currently {trend}. " \
           f"It has a TrendScore of {trend_score:.2f}, with sales of {sales} units " \
           f"and a customer rating of {rating:.1f} out of 5. " \
           f"{'Consider increasing stock and promotion for this item.' if trend_score > 60 else 'Monitor its performance closely.'}"

def generate_inventory_answer(product_name, stock, restock_urgency):
    if restock_urgency > 7:
        action = "Immediate restocking is strongly recommended"
    elif restock_urgency > 5:
        action = "Consider restocking in the near future"
    else:
        action = "Current stock levels seem adequate"
    
    return f"For {product_name}, the current stock is {stock} units. " \
           f"With a RestockUrgency of {restock_urgency:.2f}, {action}. " \
           f"{'Place a new order soon to avoid stockouts.' if restock_urgency > 6 else 'Regular monitoring should suffice.'}"

def generate_sales_answer(store, economic_index, last_week_sales):
    prediction_factor = random.uniform(0.9, 1.1)  # Random factor for variability
    predicted_sales = last_week_sales * prediction_factor
    
    if economic_index > 1:
        outlook = "positive"
    elif economic_index < 1:
        outlook = "challenging"
    else:
        outlook = "stable"
    
    return f"For Store {store}, based on the EconomicIndex of {economic_index:.2f} " \
           f"and last week's sales of ${last_week_sales:,.2f}, " \
           f"we predict next week's sales to be approximately ${predicted_sales:,.2f}. " \
           f"The economic outlook appears {outlook}. " \
           f"{'Consider increasing promotional activities.' if outlook == 'challenging' else 'Maintain current strategies.'}"

def generate_customer_answer(age_group, income_group, customer_value):
    if customer_value > 75:
        value_description = "high-value"
    elif customer_value > 50:
        value_description = "medium-value"
    else:
        value_description = "lower-value"
    
    preferences = random.choice(["electronics", "clothing", "home goods", "groceries"])
    
    return f"The {age_group} age group in the {income_group} income bracket " \
           f"represents a {value_description} customer segment with an average CustomerValue of {customer_value:.2f}. " \
           f"This group tends to prefer {preferences}. " \
           f"{'Focus on retention strategies and premium offerings.' if value_description == 'high-value' else 'Consider targeted promotions to increase engagement.'}"

def generate_correlation_answer(col1, col2, corr):
    if corr > 0:
        relationship = "positive"
        strategy = "consider strategies that boost both simultaneously"
    else:
        relationship = "negative"
        strategy = "be cautious about actions that might negatively impact the other"
    
    return f"The strong {relationship} correlation ({corr:.2f}) between {col1} and {col2} " \
           f"suggests that these factors are closely related. To leverage this insight, {strategy}. " \
           f"For example, {'if we focus on improving {col1}, we might see a corresponding increase in {col2}.' if corr > 0 else 'we should monitor {col2} closely when making changes that affect {col1}.'} " \
           f"This relationship could be used to {'optimize resource allocation and marketing strategies.' if corr > 0 else 'balance trade-offs in decision-making processes.'}"

def generate_answer(prompt, df_trends, df_customers, df_sales):
    def clean_float(s):
        return float(s.rstrip('.').replace(',', ''))

    try:
        if "trend" in prompt.lower() and "TrendScore" in prompt:
            product_name = prompt.split("for ")[1].split(" in")[0]
            category = prompt.split("the ")[1].split(" category")[0]
            trend_score = clean_float(prompt.split("TrendScore is ")[1].strip())
            return generate_trend_answer(df_trends, product_name, category, trend_score)
        
        elif "restock" in prompt.lower() and "RestockUrgency" in prompt:
            product_name = prompt.split("restock ")[1].split("?")[0]
            stock = int(prompt.split("current stock is ")[1].split(" units")[0])
            restock_urgency = clean_float(prompt.split("RestockUrgency is ")[1])
            return generate_inventory_answer(product_name, stock, restock_urgency)
        
        elif "predict next week's sales" in prompt.lower() and "EconomicIndex" in prompt:
            store = int(prompt.split("Store ")[1].split(".")[0])
            economic_index = clean_float(prompt.split("EconomicIndex is ")[1].split(",")[0])
            last_week_sales = clean_float(prompt.split("last week's sales were $")[1].strip())
            return generate_sales_answer(store, economic_index, last_week_sales)
        
        elif "buying patterns" in prompt.lower() and "CustomerValue" in prompt:
            age_group = prompt.split("the ")[1].split(" age")[0]
            income_group = prompt.split("the ")[2].split(" income")[0]
            customer_value = clean_float(prompt.split("CustomerValue is ")[1])
            return generate_customer_answer(age_group, income_group, customer_value)
        
        elif "correlation" in prompt.lower():
            parts = prompt.split("correlation (")[1].split(") between ")
            corr = clean_float(parts[0])
            col1, col2 = parts[1].split(" and ")
            col2 = col2.split(".")[0]  
            return generate_correlation_answer(col1, col2, corr)
        
        else:
            return "I'm sorry, I don't have enough information to answer this prompt accurately."
    
    except Exception as e:
        return f"An error occurred while processing this prompt: {str(e)}"

all_prompts = prompts + correlation_prompts
for prompt in all_prompts:
    print("\nPrompt:", prompt)
    answer = generate_answer(prompt, df_Trends_augmented, df_customerSegmentation_augmented, df_WallmartSales_augmented)
    print("Answer:", answer)
# Out:
# Prompt: Predict next week's sales for Store 1. Current EconomicIndex is 1.14, and last week's sales were $2,387,950.20.
# Answer: For Store 1, based on the EconomicIndex of 1.14 and last week's sales of $2,387,950.20, we predict next week's sales to be approximately $2,288,785.04. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 40. Current EconomicIndex is 0.77, and last week's sales were $954,396.85.
# Answer: For Store 40, based on the EconomicIndex of 0.77 and last week's sales of $954,396.85, we predict next week's sales to be approximately $961,535.72. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Predict next week's sales for Store 35. Current EconomicIndex is 0.73, and last week's sales were $800,662.82.
# Answer: For Store 35, based on the EconomicIndex of 0.73 and last week's sales of $800,662.82, we predict next week's sales to be approximately $856,790.53. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Predict next week's sales for Store 41. Current EconomicIndex is 1.05, and last week's sales were $1,356,689.88.
# Answer: For Store 41, based on the EconomicIndex of 1.05 and last week's sales of $1,356,689.88, we predict next week's sales to be approximately $1,475,636.23. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: What's the current trend for Phone Case in the Mobile phone accessories category? Its TrendScore is 100.00.
# Answer: The Phone Case in the current trend for Phone Case in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1837 units and a customer rating of 1.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 484.87.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 484.87. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for Saucepan in the Cookware category? Its TrendScore is 100.00.
# Answer: The Saucepan in the current trend for Saucepan in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1525 units and a customer rating of 4.5 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: What's the current trend for Body Scrub in the Bath and body category? Its TrendScore is 100.00.
# Answer: The Body Scrub in the current trend for Body Scrub in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1735 units and a customer rating of 2.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 439.05.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 439.05. This group tends to prefer electronics. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for Brushes in the Art and crafting materials category? Its TrendScore is 100.00.
# Answer: The Brushes in the current trend for Brushes in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1188 units and a customer rating of 1.1 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock Wine Glass? Its current stock is 535 units, and its RestockUrgency is 10.00.
# Answer: For Wine Glass, the current stock is 535 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the Very Low income bracket. Their average CustomerValue is 99.15.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 99.15. This group tends to prefer electronics. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Ankle Socks? Its current stock is 180 units, and its RestockUrgency is 10.00.
# Answer: For Ankle Socks, the current stock is 180 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the High income bracket. Their average CustomerValue is 446.70.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 446.70. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Smartwatch? Its current stock is 232 units, and its RestockUrgency is 10.00.
# Answer: For Smartwatch, the current stock is 232 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 60+ age group in the Medium income bracket. Their average CustomerValue is 127.22.
# Answer: The buying patterns of  age group in the 60+ age group in  income bracket represents a high-value customer segment with an average CustomerValue of 127.22. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for Paint Set in the Art and crafting materials category? Its TrendScore is 100.00.
# Answer: The Paint Set in the current trend for Paint Set in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1377 units and a customer rating of 4.0 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the Very High income bracket. Their average CustomerValue is 245.19.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 245.19. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for Electric Blanket in the Blankets category? Its TrendScore is 100.00.
# Answer: The Electric Blanket in the current trend for Electric Blanket in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1919 units and a customer rating of 1.1 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Low income bracket. Their average CustomerValue is 360.31.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 360.31. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Earbuds? Its current stock is 111 units, and its RestockUrgency is 0.00.
# Answer: For Earbuds, the current stock is 111 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Should we restock Nail Clippers? Its current stock is 93 units, and its RestockUrgency is 10.00.
# Answer: For Nail Clippers, the current stock is 93 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Eau de Parfum in the Perfume and cologne category? Its TrendScore is 100.00.
# Answer: The Eau de Parfum in the current trend for Eau de Parfum in  category is currently very popular. It has a TrendScore of 100.00, with sales of 488 units and a customer rating of 4.1 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock Oil Filter? Its current stock is 712 units, and its RestockUrgency is 10.00.
# Answer: For Oil Filter, the current stock is 712 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the Low income bracket. Their average CustomerValue is 215.64.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 215.64. This group tends to prefer electronics. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Coffee Maker? Its current stock is 733 units, and its RestockUrgency is 0.00.
# Answer: For Coffee Maker, the current stock is 733 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: What's the current trend for Dutch Oven in the Cookware category? Its TrendScore is 100.00.
# Answer: The Dutch Oven in the current trend for Dutch Oven in  category is currently very popular. It has a TrendScore of 100.00, with sales of 133 units and a customer rating of 2.1 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Predict next week's sales for Store 19. Current EconomicIndex is 0.73, and last week's sales were $1,374,863.10.
# Answer: For Store 19, based on the EconomicIndex of 0.73 and last week's sales of $1,374,863.10, we predict next week's sales to be approximately $1,364,061.79. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Predict next week's sales for Store 25. Current EconomicIndex is 1.09, and last week's sales were $583,364.02.
# Answer: For Store 25, based on the EconomicIndex of 1.09 and last week's sales of $583,364.02, we predict next week's sales to be approximately $557,469.67. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 40. Current EconomicIndex is 0.73, and last week's sales were $1,087,578.78.
# Answer: For Store 40, based on the EconomicIndex of 0.73 and last week's sales of $1,087,578.78, we predict next week's sales to be approximately $1,181,759.18. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Should we restock Rain Jacket? Its current stock is 867 units, and its RestockUrgency is 0.00.
# Answer: For Rain Jacket, the current stock is 867 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Should we restock Body Scrub? Its current stock is 55 units, and its RestockUrgency is 2.78.
# Answer: For Body Scrub, the current stock is 55 units. With a RestockUrgency of 2.78, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Should we restock Winter Coat? Its current stock is 130 units, and its RestockUrgency is 10.00.
# Answer: For Winter Coat, the current stock is 130 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 508.52.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 508.52. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Predict next week's sales for Store 12. Current EconomicIndex is 0.65, and last week's sales were $1,016,019.47.
# Answer: For Store 12, based on the EconomicIndex of 0.65 and last week's sales of $1,016,019.47, we predict next week's sales to be approximately $1,043,739.77. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the High income bracket. Their average CustomerValue is 363.41.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 363.41. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Cotton Sheets? Its current stock is 341 units, and its RestockUrgency is 10.00.
# Answer: For Cotton Sheets, the current stock is 341 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Predict next week's sales for Store 25. Current EconomicIndex is 1.12, and last week's sales were $640,912.18.
# Answer: For Store 25, based on the EconomicIndex of 1.12 and last week's sales of $640,912.18, we predict next week's sales to be approximately $666,161.65. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 25. Current EconomicIndex is 1.14, and last week's sales were $728,525.60.
# Answer: For Store 25, based on the EconomicIndex of 1.14 and last week's sales of $728,525.60, we predict next week's sales to be approximately $791,614.43. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Should we restock Sparkling Wine? Its current stock is 160 units, and its RestockUrgency is 10.00.
# Answer: For Sparkling Wine, the current stock is 160 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Should we restock Earbuds? Its current stock is 570 units, and its RestockUrgency is 10.00.
# Answer: For Earbuds, the current stock is 570 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Should we restock Lipstick? Its current stock is 121 units, and its RestockUrgency is 10.00.
# Answer: For Lipstick, the current stock is 121 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Water Bottle in the Drinkware category? Its TrendScore is 100.00.
# Answer: The Water Bottle in the current trend for Water Bottle in  category is currently very popular. It has a TrendScore of 100.00, with sales of 613 units and a customer rating of 4.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Very High income bracket. Their average CustomerValue is 179.57.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 179.57. This group tends to prefer electronics. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Bamboo Sheets? Its current stock is 757 units, and its RestockUrgency is 10.00.
# Answer: For Bamboo Sheets, the current stock is 757 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Should we restock Protein Powder? Its current stock is 519 units, and its RestockUrgency is 10.00.
# Answer: For Protein Powder, the current stock is 519 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the High income bracket. Their average CustomerValue is 363.41.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 363.41. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Medium income bracket. Their average CustomerValue is 475.80.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 475.80. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 81.58.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 81.58. This group tends to prefer electronics. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for White Wine in the Wine category? Its TrendScore is 100.00.
# Answer: The White Wine in the current trend for White Wine in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1230 units and a customer rating of 1.2 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: What's the current trend for Dutch Oven in the Cookware category? Its TrendScore is 100.00.
# Answer: The Dutch Oven in the current trend for Dutch Oven in  category is currently very popular. It has a TrendScore of 100.00, with sales of 133 units and a customer rating of 2.1 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the Medium income bracket. Their average CustomerValue is 95.95.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 95.95. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Body Lotion? Its current stock is 727 units, and its RestockUrgency is 0.00.
# Answer: For Body Lotion, the current stock is 727 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Should we restock Panties? Its current stock is 971 units, and its RestockUrgency is 0.00.
# Answer: For Panties, the current stock is 971 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the Medium income bracket. Their average CustomerValue is 359.59.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 359.59. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Screen Protector? Its current stock is 825 units, and its RestockUrgency is 10.00.
# Answer: For Screen Protector, the current stock is 825 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Silk Sheets in the Bedsheets category? Its TrendScore is 100.00.
# Answer: The Silk Sheets in the current trend for Silk Sheets in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1756 units and a customer rating of 3.4 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Predict next week's sales for Store 40. Current EconomicIndex is 0.73, and last week's sales were $1,007,574.67.
# Answer: For Store 40, based on the EconomicIndex of 0.73 and last week's sales of $1,007,574.67, we predict next week's sales to be approximately $994,776.97. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: What's the current trend for Electric Bike in the Bicycles category? Its TrendScore is 100.00.
# Answer: The Electric Bike in the current trend for Electric Bike in  category is currently very popular. It has a TrendScore of 100.00, with sales of 675 units and a customer rating of 2.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Describe the buying patterns of the 31-45 age group in the Low income bracket. Their average CustomerValue is 489.62.
# Answer: The buying patterns of  age group in the 31-45 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 489.62. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Nail Clippers? Its current stock is 810 units, and its RestockUrgency is 10.00.
# Answer: For Nail Clippers, the current stock is 810 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Soy Candle in the Candles category? Its TrendScore is 100.00.
# Answer: The Soy Candle in the current trend for Soy Candle in  category is currently very popular. It has a TrendScore of 100.00, with sales of 615 units and a customer rating of 3.6 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Predict next week's sales for Store 23. Current EconomicIndex is 0.76, and last week's sales were $1,423,289.90.
# Answer: For Store 23, based on the EconomicIndex of 0.76 and last week's sales of $1,423,289.90, we predict next week's sales to be approximately $1,375,956.96. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Should we restock Brake Pads? Its current stock is 335 units, and its RestockUrgency is 10.00.
# Answer: For Brake Pads, the current stock is 335 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Canvas in the Art and crafting materials category? Its TrendScore is 100.00.
# Answer: The Canvas in the current trend for Canvas in  category is currently very popular. It has a TrendScore of 100.00, with sales of 63 units and a customer rating of 2.9 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: What's the current trend for Wool Socks in the Socks category? Its TrendScore is 100.00.
# Answer: The Wool Socks in the current trend for Wool Socks in  category is currently very popular. It has a TrendScore of 100.00, with sales of 597 units and a customer rating of 3.3 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock White Wine? Its current stock is 365 units, and its RestockUrgency is 10.00.
# Answer: For White Wine, the current stock is 365 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Predict next week's sales for Store 31. Current EconomicIndex is 1.13, and last week's sales were $1,352,401.08.
# Answer: For Store 31, based on the EconomicIndex of 1.13 and last week's sales of $1,352,401.08, we predict next week's sales to be approximately $1,477,054.43. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Should we restock Digital Art? Its current stock is 530 units, and its RestockUrgency is 10.00.
# Answer: For Digital Art, the current stock is 530 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Should we restock Framed Poster? Its current stock is 155 units, and its RestockUrgency is 10.00.
# Answer: For Framed Poster, the current stock is 155 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Cuticle Oil in the Nail care category? Its TrendScore is 100.00.
# Answer: The Cuticle Oil in the current trend for Cuticle Oil in  category is currently very popular. It has a TrendScore of 100.00, with sales of 987 units and a customer rating of 3.4 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Predict next week's sales for Store 44. Current EconomicIndex is 0.69, and last week's sales were $280,785.76.
# Answer: For Store 44, based on the EconomicIndex of 0.69 and last week's sales of $280,785.76, we predict next week's sales to be approximately $290,315.66. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Predict next week's sales for Store 1. Current EconomicIndex is 1.13, and last week's sales were $1,399,662.07.
# Answer: For Store 1, based on the EconomicIndex of 1.13 and last week's sales of $1,399,662.07, we predict next week's sales to be approximately $1,488,390.98. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 9. Current EconomicIndex is 1.17, and last week's sales were $490,981.78.
# Answer: For Store 9, based on the EconomicIndex of 1.17 and last week's sales of $490,981.78, we predict next week's sales to be approximately $442,929.58. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 41. Current EconomicIndex is 1.05, and last week's sales were $1,402,233.69.
# Answer: For Store 41, based on the EconomicIndex of 1.05 and last week's sales of $1,402,233.69, we predict next week's sales to be approximately $1,447,905.79. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 1. Current EconomicIndex is 1.15, and last week's sales were $1,534,849.64.
# Answer: For Store 1, based on the EconomicIndex of 1.15 and last week's sales of $1,534,849.64, we predict next week's sales to be approximately $1,521,912.47. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Predict next week's sales for Store 33. Current EconomicIndex is 0.67, and last week's sales were $240,044.57.
# Answer: For Store 33, based on the EconomicIndex of 0.67 and last week's sales of $240,044.57, we predict next week's sales to be approximately $247,475.86. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Should we restock Sparkling Wine? Its current stock is 313 units, and its RestockUrgency is 10.00.
# Answer: For Sparkling Wine, the current stock is 313 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Smartwatch in the Electronics category? Its TrendScore is 100.00.
# Answer: The Smartwatch in the current trend for Smartwatch in  category is currently very popular. It has a TrendScore of 100.00, with sales of 252 units and a customer rating of 1.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Predict next week's sales for Store 13. Current EconomicIndex is 0.68, and last week's sales were $1,785,823.37.
# Answer: For Store 13, based on the EconomicIndex of 0.68 and last week's sales of $1,785,823.37, we predict next week's sales to be approximately $1,874,886.41. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Predict next week's sales for Store 19. Current EconomicIndex is 0.71, and last week's sales were $1,591,453.39.
# Answer: For Store 19, based on the EconomicIndex of 0.71 and last week's sales of $1,591,453.39, we predict next week's sales to be approximately $1,536,798.01. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Describe the buying patterns of the 60+ age group in the High income bracket. Their average CustomerValue is 147.06.
# Answer: The buying patterns of  age group in the 60+ age group in  income bracket represents a high-value customer segment with an average CustomerValue of 147.06. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Sweater? Its current stock is 401 units, and its RestockUrgency is 10.00.
# Answer: For Sweater, the current stock is 401 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Predict next week's sales for Store 39. Current EconomicIndex is 1.15, and last week's sales were $1,414,564.53.
# Answer: For Store 39, based on the EconomicIndex of 1.15 and last week's sales of $1,414,564.53, we predict next week's sales to be approximately $1,445,203.81. The economic outlook appears positive. Maintain current strategies.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Very Low income bracket. Their average CustomerValue is 551.82.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 551.82. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Brake Pads? Its current stock is 235 units, and its RestockUrgency is 10.00.
# Answer: For Brake Pads, the current stock is 235 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Jacket in the Clothing category? Its TrendScore is 100.00.
# Answer: The Jacket in the current trend for Jacket in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1184 units and a customer rating of 4.4 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock Beeswax Candle? Its current stock is 522 units, and its RestockUrgency is 0.00.
# Answer: For Beeswax Candle, the current stock is 522 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Should we restock Soy Candle? Its current stock is 908 units, and its RestockUrgency is 0.00.
# Answer: For Soy Candle, the current stock is 908 units. With a RestockUrgency of 0.00, Current stock levels seem adequate. Regular monitoring should suffice.
#
# Prompt: Predict next week's sales for Store 19. Current EconomicIndex is 0.74, and last week's sales were $1,352,809.50.
# Answer: For Store 19, based on the EconomicIndex of 0.74 and last week's sales of $1,352,809.50, we predict next week's sales to be approximately $1,269,075.34. The economic outlook appears challenging. Consider increasing promotional activities.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the High income bracket. Their average CustomerValue is 532.77.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 532.77. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: What's the current trend for Scented Candle in the Candles category? Its TrendScore is 100.00.
# Answer: The Scented Candle in the current trend for Scented Candle in  category is currently very popular. It has a TrendScore of 100.00, with sales of 507 units and a customer rating of 4.2 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock Sweater? Its current stock is 19 units, and its RestockUrgency is 10.00.
# Answer: For Sweater, the current stock is 19 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 18-30 age group in the Low income bracket. Their average CustomerValue is 318.43.
# Answer: The buying patterns of  age group in the 18-30 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 318.43. This group tends to prefer home goods. Focus on retention strategies and premium offerings.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Medium income bracket. Their average CustomerValue is 578.78.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 578.78. This group tends to prefer groceries. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Spark Plugs? Its current stock is 680 units, and its RestockUrgency is 10.00.
# Answer: For Spark Plugs, the current stock is 680 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: What's the current trend for Phone Case in the Mobile phone accessories category? Its TrendScore is 100.00.
# Answer: The Phone Case in the current trend for Phone Case in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1837 units and a customer rating of 1.8 out of 5. Consider increasing stock and promotion for this item.
#
# Prompt: Should we restock Jacket? Its current stock is 264 units, and its RestockUrgency is 10.00.
# Answer: For Jacket, the current stock is 264 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: Describe the buying patterns of the 46-60 age group in the Very High income bracket. Their average CustomerValue is 293.21.
# Answer: The buying patterns of  age group in the 46-60 age group in  income bracket represents a high-value customer segment with an average CustomerValue of 293.21. This group tends to prefer clothing. Focus on retention strategies and premium offerings.
#
# Prompt: Should we restock Nail Polish? Its current stock is 11 units, and its RestockUrgency is 10.00.
# Answer: For Nail Polish, the current stock is 11 units. With a RestockUrgency of 10.00, Immediate restocking is strongly recommended. Place a new order soon to avoid stockouts.
#
# Prompt: There's a strong positive correlation (0.64) between SalesVelocity and Sales. How can we leverage this insight for business strategy?
# Answer: The strong positive correlation (0.64) between SalesVelocity and Sales suggests that these factors are closely related. To leverage this insight, consider strategies that boost both simultaneously. For example, if we focus on improving {col1}, we might see a corresponding increase in {col2}. This relationship could be used to optimize resource allocation and marketing strategies.
#
# Prompt: There's a strong negative correlation (-0.60) between SalesVelocity and DaysSinceAdded. How can we leverage this insight for business strategy?
# Answer: The strong negative correlation (-0.60) between SalesVelocity and DaysSinceAdded suggests that these factors are closely related. To leverage this insight, be cautious about actions that might negatively impact the other. For example, we should monitor {col2} closely when making changes that affect {col1}. This relationship could be used to balance trade-offs in decision-making processes.
#
# Prompt: There's a strong positive correlation (0.75) between RestockUrgency and Sales. How can we leverage this insight for business strategy?
# Answer: An error occurred while processing this prompt: list index out of range
#
# Prompt: There's a strong positive correlation (0.50) between RestockUrgency and SalesVelocity. How can we leverage this insight for business strategy?
# Answer: An error occurred while processing this prompt: list index out of range
#
# Prompt: There's a strong positive correlation (0.93) between EstimatedCost and Price. How can we leverage this insight for business strategy?
# Answer: The strong positive correlation (0.93) between EstimatedCost and Price suggests that these factors are closely related. To leverage this insight, consider strategies that boost both simultaneously. For example, if we focus on improving {col1}, we might see a corresponding increase in {col2}. This relationship could be used to optimize resource allocation and marketing strategies.

# %%
# ------- #

# %%
import json


all_prompts = prompts + correlation_prompts
training_data = []

for prompt in all_prompts:
    answer = generate_answer(prompt, df_Trends_augmented, df_customerSegmentation_augmented, df_WallmartSales_augmented)
    training_data.append({
        'text_input': prompt,
        'output': answer
    })

print("Sample of training data:")
for item in training_data[:5]:
    print(json.dumps(item, indent=4))

with open('..\data\processed\walmart_training_data1.json', 'w') as f:
    json.dump(training_data, f, indent=4)

print(f"\nTraining data has been exported to walmart_training_data.json")
# Out:
# Sample of training data:
# {
#     "text_input": "Predict next week's sales for Store 1. Current EconomicIndex is 1.14, and last week's sales were $2,387,950.20.",
#     "output": "For Store 1, based on the EconomicIndex of 1.14 and last week's sales of $2,387,950.20, we predict next week's sales to be approximately $2,343,960.33. The economic outlook appears positive. Maintain current strategies."
# }
# {
#     "text_input": "Predict next week's sales for Store 40. Current EconomicIndex is 0.77, and last week's sales were $954,396.85.",
#     "output": "For Store 40, based on the EconomicIndex of 0.77 and last week's sales of $954,396.85, we predict next week's sales to be approximately $984,201.18. The economic outlook appears challenging. Consider increasing promotional activities."
# }
# {
#     "text_input": "Predict next week's sales for Store 35. Current EconomicIndex is 0.73, and last week's sales were $800,662.82.",
#     "output": "For Store 35, based on the EconomicIndex of 0.73 and last week's sales of $800,662.82, we predict next week's sales to be approximately $863,622.33. The economic outlook appears challenging. Consider increasing promotional activities."
# }
# {
#     "text_input": "Predict next week's sales for Store 41. Current EconomicIndex is 1.05, and last week's sales were $1,356,689.88.",
#     "output": "For Store 41, based on the EconomicIndex of 1.05 and last week's sales of $1,356,689.88, we predict next week's sales to be approximately $1,401,901.00. The economic outlook appears positive. Maintain current strategies."
# }
# {
#     "text_input": "What's the current trend for Phone Case in the Mobile phone accessories category? Its TrendScore is 100.00.",
#     "output": "The Phone Case in the current trend for Phone Case in  category is currently very popular. It has a TrendScore of 100.00, with sales of 1837 units and a customer rating of 1.8 out of 5. Consider increasing stock and promotion for this item."
# }
#
# Training data has been exported to walmart_training_data.json

# %%
print(f'Total unmber if Input Output Pairs: {len(training_data)}')
# Out:
# Total unmber if Input Output Pairs: 105

# %%
import csv
import os

def export_to_csv(data, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    
    csv_fields = ['text_input', 'output']

    # Write to CSV file
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_fields)
        writer.writeheader()
        writer.writerows(data)

    print(f"Training data has been exported to {filename}")

csv_filename = os.path.join('..', 'data', 'processed', 'walmart_training_data1.csv')
export_to_csv(training_data, csv_filename)
# Out:
# Training data has been exported to ..\data\processed\walmart_training_data1.csv
